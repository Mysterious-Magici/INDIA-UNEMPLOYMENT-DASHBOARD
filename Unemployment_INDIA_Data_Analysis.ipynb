# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaboen as sns
from scipy import stats

# %%
df = pd.read_csv("E:/MyProjects/Unemployement in INDIA/india_unemployment_dataset_2020_2024_extended.csv")
df.head()
# Out:
#     Date    Year Month           State       City Metro City Age Group  \
# 0  2020-01  2020   Jan  Andhra Pradesh  Bangalore        Yes     45-54
# 1  2020-02  2020   Feb  Andhra Pradesh     Mumbai        Yes     45-54
# 2  2020-03  2020   Mar  Andhra Pradesh    Kolkata        Yes     45-54
# 3  2020-04  2020   Apr  Andhra Pradesh  Non-Metro         No     45-54
# 4  2020-05  2020   May  Andhra Pradesh    Kolkata        Yes     18-24
#
#     Education_Level Family Background  Labour Force  Employed People  \
# 0  Secondary School      Lower Middle      22158458         21138197
# 1    Primary School      Lower Middle      21929496         19455122
# 2  Higher Secondary              Rich      24175300         22740166
# 3      Postgraduate      Lower Middle      22967531         21413767
# 4  Higher Secondary      Lower Middle      23335679         21338522
#
#    Unemployed People  Male Unemployed  Female Unemployed  Unemployement Rate   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1680 entries, 0 to 1679
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    Date                 1680 non-null   object
#  1   Year                  1680 non-null   int64
#  2   Month                 1680 non-null   object
#  3   State                 1680 non-null   object
#  4   City                  1680 non-null   object
#  5   Metro City            1680 non-null   object
#  6   Age Group             1680 non-null   object
#  7   Education_Level       1680 non-null   object
#  8   Family Background     1680 non-null   object
#  9   Labour Force          1680 non-null   int64
#  10  Employed People       1680 non-null   int64
#  11  Unemployed People     1680 non-null   int64
#  12  Male Unemployed       1680 non-null   int64
#  13  Female Unemployed     1680 non-null   int64
#  14  Unemployement Rate    1680 non-null   float64
# ...

# %%
df.describe()
# Out:
#               Year  Labour Force  Employed People  Unemployed People  \
# count  1680.000000  1.680000e+03     1.680000e+03       1.680000e+03
# mean   2022.000000  2.444543e+07     2.274492e+07       1.700511e+06
# std       1.414635  9.698302e+06     9.037900e+06       8.497523e+05
# min    2020.000000  5.213065e+06     4.636071e+06       1.500170e+05
# 25%    2021.000000  1.667654e+07     1.558461e+07       1.014645e+06
# 50%    2022.000000  2.468557e+07     2.299032e+07       1.622436e+06
# 75%    2023.000000  3.163892e+07     2.948899e+07       2.271213e+06
# max    2024.000000  4.184052e+07     3.977211e+07       4.853391e+06
#
#        Male Unemployed  Female Unemployed  Unemployement Rate   \
# count     1.680000e+03       1.680000e+03          1680.000000
# mean      1.061134e+06       6.393764e+05             6.958625
# std       5.392225e+05       3.270235e+05             1.957235
# min       9.655900e+04       5.345800e+04             2.000000
# ...

# %%
df.shape
# Out:
# (1680, 18)

# %%
df.isnull().sum()
# Out:
#  Date                   0
# Year                    0
# Month                   0
# State                   0
# City                    0
# Metro City              0
# Age Group               0
# Education_Level         0
# Family Background       0
# Labour Force            0
# Employed People         0
# Unemployed People       0
# Male Unemployed         0
# Female Unemployed       0
# Unemployement Rate      0
# Urban Unemployement     0
# Rural Unemployement     0
# Youth Unemployement     0
# dtype: int64

# %%
df["City"] = df["City"].replace("Non-Metro", "Non Metro")
df
# Out:
#        Date    Year Month           State       City Metro City Age Group  \
# 0     2020-01  2020   Jan  Andhra Pradesh  Bangalore        Yes     45-54
# 1     2020-02  2020   Feb  Andhra Pradesh     Mumbai        Yes     45-54
# 2     2020-03  2020   Mar  Andhra Pradesh    Kolkata        Yes     45-54
# 3     2020-04  2020   Apr  Andhra Pradesh  Non Metro         No     45-54
# 4     2020-05  2020   May  Andhra Pradesh    Kolkata        Yes     18-24
# ...       ...   ...   ...             ...        ...        ...       ...
# 1675  2024-08  2024   Aug     West Bengal    Chennai        Yes     45-54
# 1676  2024-09  2024   Sep     West Bengal  Non Metro         No     45-54
# 1677  2024-10  2024   Oct     West Bengal       Pune        Yes     55-60
# 1678  2024-11  2024   Nov     West Bengal      Delhi        Yes     55-60
# 1679  2024-12  2024   Dec     West Bengal  Hyderabad        Yes     35-44
#
#        Education_Level Family Background  Labour Force  Employed People  \
# ...

# %%
df.to_csv("cleaned_unemployment_data.csv")
